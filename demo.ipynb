# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import networkx as nx

import viewnet 
import measure_perc as mp

# %%
# note the seed 3 is used arbitrarily for demo purposes
collection=viewnet.Netviewer(n=300,scaling=5,l=0.66,seed=3)

# %%
info=collection.get_info()
# Out:
# === input parameters ===
# number of sticks: 300
# stick length : 0.66 ± 0.44 μm
# percentage metallic: 0.135 %
#
# === physical network characteristics ===
# device region: 5x5 μm
# stick density: 12.0 sticks/μm^2
# number of clusters: 6
# size of stick clusters: 48.83 ± 85.20 sticks
# maximum cluster size: 238 sticks
#
# === electrical characteristics ===
# device conducting: True
# driving voltage: 0.1 V
# device current: 0.01 A
# current variation (std dev across sticks): 5.59e-04 ± 1.20e-03 A

# %%
collection.show_system(figsize=(10,10))

# %%
data=mp.measure_async(3,2,1,100,2,onoffmap=[0])
# Out:
# 100
# finished with a runtime of 8 seconds

# %%
plt.scatter(data.density,data.ion)
plt.scatter(data[data.ion!=0].density,data[data.ion!=0].ion)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 222 entries, 0 to 2
# Data columns (total 12 columns):
# sticks      222 non-null object
# size        222 non-null object
# density     222 non-null float64
# nclust      222 non-null object
# maxclust    222 non-null object
# ion         222 non-null object
# ioff        222 non-null object
# gate        222 non-null object
# fname       222 non-null object
# seed        222 non-null object
# onoffmap    222 non-null object
# runtime     222 non-null float64
# dtypes: float64(2), object(10)
# memory usage: 27.5+ KB
