# %%
# %load_ext autoreload

# %%
# %autoreload 2

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import networkx as nx

import viewnet 
import measure_perc as mp
import percolation as perc

# %%
look=viewnet.Netviewer(n=300,scaling=5,l='exp',seed=3,pm=0.13)
look.show_system(figsize=(6.3,4))
# Out:
# /home/leo/.virtualenvs/networkenv/lib/python3.5/site-packages/matplotlib/figure.py:2022: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   warnings.warn("This figure includes Axes that are not compatible "
# (<matplotlib.figure.Figure at 0x7fde0d3f9438>, <numpy.flatiter at 0x3210140>)

# %%
look.plot_contour('current')

# %%
p=perc.CNTDevice(scaling=1,n=20)
sorted(vars(p).keys())
# Out:
# ['cnet',
#  'directory',
#  'element',
#  'fname',
#  'gatetype',
#  'gatevoltage',
#  'graph',
#  'ground_nodes',
#  'intersects',
#  'l',
#  'n',
#  'notes',
#  'onoffmap',
#  'percolating',
#  'pm',
#  'scaling',
#  'seed',
#  'sticks',
#  'voltage_sources']

# %%
perc.TestClass()
# Out:
# testclass initialized
