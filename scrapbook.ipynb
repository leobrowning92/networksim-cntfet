# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import networkx as nx

import viewnet 
import measure_perc as mp
import percolation as perc

# %%
look=viewnet.Netviewer(n=10,scaling=1,l='exp',seed=2)
look.show_system()

# %%
sum(look.cnet.source_currents)
# Out:
# 0.03333333333333335
