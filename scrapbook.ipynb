# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import networkx as nx

import viewnet 
import measure_perc as mp
import percolation as perc

# %%
look=viewnet.Netviewer(n=10,scaling=1,l='exp',seed=2,pm=0.5)
look.show_system()
